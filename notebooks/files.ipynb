# %%
import nibabel as nib
from glob import glob

# %%
images = sorted(glob("../input/mri/*.nii.gz"))
segs = sorted(glob("../input/masks/*.nii"))

# %%
for img, seg in zip(images, segs):
    print(nib.load(img).shape, nib.load(seg).shape)
# Out:
# (320, 320, 39) (320, 320, 39)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 40) (320, 320, 40)
# (320, 320, 35) (320, 320, 35)
# (320, 320, 32) (320, 320, 32)
# (320, 320, 32) (320, 320, 32)
# (320, 320, 40) (320, 320, 40)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 40) (320, 320, 40)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 36) (320, 320, 36)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 40) (320, 320, 40)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 35) (320, 320, 35)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 36) (320, 320, 36)
# (320, 320, 35) (320, 320, 35)
# (320, 320, 38) (320, 320, 38)
# (320, 320, 32) (320, 320, 32)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 40) (320, 320, 40)
# (320, 320, 34) (320, 320, 34)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 32) (320, 320, 32)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 30) (320, 320, 30)
# (320, 320, 32) (320, 320, 32)
# (320, 320, 34) (320, 320, 34)
# ...
